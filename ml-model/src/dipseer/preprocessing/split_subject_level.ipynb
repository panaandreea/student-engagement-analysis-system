# %%
import random

# %%
# group 01

random.seed(0)

right_subjects = ["S01", "S02", "S03", "S11", "S12", "S13"]
central_subjects = ["S04", "S05", "S06", "S07", "S14", "S15", "S16", "S17"]
left_subjects = ["S08", "S09", "S10", "S18", "S19", "S20"]

zones = {
    "right": right_subjects,
    "central": central_subjects,
    "left": left_subjects
}

split_config = {
    "right": {"train":4, "val":1, "test":1},
    "central": {"train":6, "val":1, "test":1},
    "left": {"train":4, "val":1, "test":1}
}

train, val, test = [], [], []

for zone, subjects in zones.items():
    subjects = subjects.copy()
    random.shuffle(subjects)

    n_test = split_config[zone]["test"]
    n_val = split_config[zone]["val"]

    test.extend(subjects[:n_test])
    val.extend(subjects[n_test:n_test + n_val])
    train.extend(subjects[n_test + n_val:])

print("TRAIN:", train)
print("VAL:", val)
print("TEST:", test)
# Out:
# TRAIN: ['S02', 'S01', 'S13', 'S11', 'S14', 'S15', 'S07', 'S06', 'S17', 'S16', 'S08', 'S10', 'S09', 'S19']
# VAL: ['S03', 'S04', 'S18']
# TEST: ['S12', 'S05', 'S20']

# %%
# group 02

random.seed(42)

right_subjects = ["S01", "S21", "S02", "S03", "S11", "S12", "S13"]
central_subjects = ["S04", "S05", "S06", "S07", "S14", "S15", "S16", "S17"]
left_subjects = ["S08", "S09", "S10", "S18", "S19", "S20"]

zones = {
    "right": right_subjects,
    "central": central_subjects,
    "left": left_subjects
}

split_config = {
    "right": {"train":5, "val":1, "test":1},
    "central": {"train":6, "val":1, "test":1},
    "left": {"train":4, "val":1, "test":1}
}

train, val, test = [], [], []

for zone, subjects in zones.items():
    subjects = subjects.copy()
    random.shuffle(subjects)

    n_test = split_config[zone]["test"]
    n_val = split_config[zone]["val"]

    test.extend(subjects[:n_test])
    val.extend(subjects[n_test:n_test + n_val])
    train.extend(subjects[n_test + n_val:])

print("TRAIN:", train)
print("VAL:", val)
print("TEST:", test)
# Out:
# TRAIN: ['S11', 'S02', 'S13', 'S01', 'S12', 'S17', 'S16', 'S14', 'S04', 'S15', 'S06', 'S18', 'S19', 'S20', 'S08']
# VAL: ['S03', 'S05', 'S10']
# TEST: ['S21', 'S07', 'S09']

# %%
# group 03

random.seed(2023)

right_subjects = ["S08", "S07", "S09"]
central_subjects = ["S01", "S02", "S03", "S10", "S11", "S12", "S13"]
left_subjects = ["S04", "S05", "S06", "S14", "S15", "S16"]


zones = {
    "right": right_subjects,
    "central": central_subjects,
    "left": left_subjects
}

split_config = {
    "right": {"train":2, "val":0, "test":1},
    "central": {"train":5, "val":1, "test":1},
    "left": {"train":4, "val":1, "test":1}
}

train, val, test = [], [], []

for zone, subjects in zones.items():
    subjects = subjects.copy()
    random.shuffle(subjects)

    n_test = split_config[zone]["test"]
    n_val = split_config[zone]["val"]

    test.extend(subjects[:n_test])
    val.extend(subjects[n_test:n_test + n_val])
    train.extend(subjects[n_test + n_val:])

print("TRAIN:", train)
print("VAL:", val)
print("TEST:", test)
# Out:
# TRAIN: ['S09', 'S07', 'S12', 'S11', 'S03', 'S10', 'S13', 'S16', 'S15', 'S06', 'S04']
# VAL: ['S01', 'S14']
# TEST: ['S08', 'S02', 'S05']
